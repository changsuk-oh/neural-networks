# %% [markdown]
# 5장 신경망 성능 향상
#
# 그림 캡쳐용

# %%
# 예제 5.2

# %%
# 예제 5.2

# %%
# 예제 5.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그림 5.4 조기 종료
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 그림 5.5 데이터 증강
#
# ![image.png](data:image/png;base64,...)

# %%
# 예제 5.4

# %%
# 예제 5.4

# %%
# 그림 5.9 ROC 곡선
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
# 예제 5.6

# %%
# 예제 5.6

# %%
# 예제 5.6
# Out:
# 63/63 [==============================] - 0s 2ms/step
# y_test: [1 0 1 0 1]
# y_pred: [1 0 1 0 1]

# %%
# 예제 5.6
# Out:
# confusion matrix
#  [[978  22]
#  [ 47 953]]
# accuracy: 0.97
# precision: 0.98
# sensitivity(recall): 0.95
# specificity: 0.98
# f1 score: 0.97
# AUC: 0.97
